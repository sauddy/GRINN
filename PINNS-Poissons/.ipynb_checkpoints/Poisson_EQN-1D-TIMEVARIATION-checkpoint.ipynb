# %%
"""Backend supported: tensorflow.compat.v1, tensorflow, pytorch"""
import deepxde as dde
import numpy as np

# Import TensorFlow and NumPy
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Concatenate, Flatten, Dense, Conv2D, MaxPool2D, Dropout, BatchNormalization, Lambda
import matplotlib.pyplot as plt

np.random.seed(1234)
tf.random.set_seed(1234)
# Out:
# Using backend: tensorflow.compat.v1
# WARNING:tensorflow:From /Users/auddy/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Enable just-in-time compilation with XLA.
#
# WARNING:tensorflow:From /Users/auddy/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/deepxde/nn/initializers.py:118: The name tf.keras.initializers.he_normal is deprecated. Please use tf.compat.v1.keras.initializers.he_normal instead.

# %% [markdown]
# ## The poisson's equation
#
# $$
# \begin{equation}
# \nabla^2 \phi =  4 \pi G \rho
# \end{equation} \tag{7}
# $$
# or rewriting interm of the field
#
#
# \begin{equation}
# \nabla \phi =  - \vec g
# % \nabla . \vec g = -4\pi G\rho
# \end{equation}
#
# $$
# \begin{equation}
# \nabla . \vec g = -4\pi G\rho
# \end{equation}
# $$
#
# The density is
#
# $$
# \begin{equation}
# \rho = \rho_1 \cos(2\pi x/\lambda - 2\pi Ct/\lambda )
# \end{equation}
# $$

# %%
## We test the solution of the POISSON's EQN 
#Set data type
DTYPE='float32'
tf.keras.backend.set_floatx(DTYPE)
#%matplotlib inline

lam = 1.0          # one wavelength

rho_1 = 0.03;       # question 2b non-linear wave propagation
rho_o = 1          # zeroth order density
C = 1
def pdeTest(x, y):
    dy_xx = dde.grad.hessian(y, x)    
    return dy_xx - 4 * np.pi * (rho_1 * tf.cos(2*np.pi*x[:, 0:1]/lam- 2*np.pi*C*x[:, 1:2]/lam))

# %%
## The Geometric Domain 
xmin = -1

## The Collocation points / the computational Domain
xmin = -1
geom = dde.geometry.Interval(xmin, 1)
timedomain = dde.geometry.TimeDomain(0, 1)
geomtime = dde.geometry.GeometryXTime(geom, timedomain)

## Boundaries

## Note in the deep XDE code by default for the periodic boundary u(0) = u(1)
## If the problem is periodic this condition will also satisfy u(-1) = u(1)
## Thus is most cases the left boundary is not needed. But we have the option here

def boundary_l(x, on_boundary):  # boundary x=-1 or x = 0 
    if xmin == -1:
        is_on_boundary_left = on_boundary and np.isclose(x[0], -1)
    else:
        is_on_boundary_left = on_boundary and np.isclose(x[0], 0)
    return is_on_boundary_left

def boundary_r(x, on_boundary):  # boundary x=1
    is_on_boundary_right = on_boundary and np.isclose(x[0], 1)

    return is_on_boundary_right


bc_l = dde.icbc.PeriodicBC(geomtime, 0, boundary_l,derivative_order=0) ## may be used when x = [-1,1] otherwise for x =[0,1] not needed

bc_r = dde.icbc.PeriodicBC(geomtime, 0, boundary_r,derivative_order=0)

## 1st order terms

bc_ll = dde.icbc.PeriodicBC(geomtime, 0, boundary_l,derivative_order=1) ##may be used when x = [-1,1]

bc_rr = dde.icbc.PeriodicBC(geomtime, 0, boundary_r,derivative_order=1)

data = dde.data.TimePDE(geomtime,
                     pdeTest,
#                      [bc_l,bc_r,bc_ll,bc_rr], ## This is needed if one need to force periodicity on the left 
                     [bc_r],          ## For x =[0,1] and default
                     num_domain=10000,
                     num_boundary=5000
                     #num_initial=5000,
                    # num_test=10000,
                   )

net = dde.nn.FNN([2] + [64] * 3 + [1], "tanh", "Glorot normal")
model_test = dde.Model(data, net)

model_test.compile("adam", lr=1e-3)
model_test.train(iterations=3000)
model_test.compile("L-BFGS")


losshistory, train_state = model_test.train()
dde.saveplot(losshistory, train_state, issave=True, isplot=True)
# Out:
# Compiling model...
# Building feed-forward neural network...
# 'build' took 0.022575 s
#
# Metal device set to: Apple M1 Pro
# /Users/auddy/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/deepxde/nn/tensorflow_compat_v1/fnn.py:114: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   return tf.layers.dense(
# 2023-03-24 14:43:32.472016: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-24 14:43:32.472447: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 'compile' took 0.216599 s
#
# Initializing variables...
# Training model...
# 2023-03-24 14:43:32.669844: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# 2023-03-24 14:43:32.677417: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-24 14:43:32.683644: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:43:32.710777: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1780] (One-time warning): Not using XLA:CPU for cluster.
#
# If you want XLA:CPU, do one of the following:
#
#  - set the TF_XLA_FLAGS to include "--tf_xla_cpu_global_jit", or
#  - set cpu_global_jit to true on this session's OptimizerOptions, or
#  - use experimental_jit_scope, or
#  - use tf.function(jit_compile=True).
#
# To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a
# proper command-line flag, not via TF_XLA_FLAGS).
# 2023-03-24 14:43:32.718609: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Step      Train loss              Test loss               Test metric
# 0         [7.17e-02, 1.48e-02]    [7.17e-02, 1.48e-02]    []
# 2023-03-24 14:43:33.353409: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:43:33.475726: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1000      [1.31e-04, 2.32e-06]    [1.31e-04, 2.32e-06]    []
# 2000      [5.29e-05, 1.43e-06]    [5.29e-05, 1.43e-06]    []
# 3000      [3.04e-05, 3.71e-07]    [3.04e-05, 3.71e-07]    []
#
# Best model at step 3000:
#   train loss: 3.08e-05
#   test loss: 3.08e-05
#   test metric: []
#
# 'train' took 65.825213 s
#
# Compiling model...
# 'compile' took 0.068474 s
#
# Training model...
# 2023-03-24 14:44:38.579668: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:44:38.598711: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:44:38.602303: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:44:38.711075: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Step      Train loss              Test loss               Test metric
# 3000      [3.04e-05, 3.71e-07]    [3.04e-05, 3.71e-07]    []
# 2023-03-24 14:44:38.822482: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:44:38.849019: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:44:39.106658: W tensorflow/compiler/jit/kernels/xla_ops.cc:466] Compilation failed:UNIMPLEMENTED: Could not find compiler for platform METAL: NOT_FOUND: could not find registered compiler for platform METAL -- was support for that platform linked in?.  Falling back to TF function call.
# 2023-03-24 14:44:39.119850: W tensorflow/compiler/jit/kernels/xla_ops.cc:466] Compilation failed:UNIMPLEMENTED: Could not find compiler for platform METAL: NOT_FOUND: could not find registered compiler for platform METAL -- was support for that platform linked in?.  Falling back to TF function call.
# 2023-03-24 14:44:39.123776: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:44:39.135346: W tensorflow/compiler/jit/kernels/xla_ops.cc:466] Compilation failed:UNIMPLEMENTED: Could not find compiler for platform METAL: NOT_FOUND: could not find registered compiler for platform METAL -- was support for that platform linked in?.  Falling back to TF function call.
# 2023-03-24 14:44:39.135689: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-03-24 14:44:39.137480: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 4000      [1.68e-07, 1.42e-09]    [1.68e-07, 1.42e-09]
# 5000      [6.46e-08, 4.06e-10]    [6.46e-08, 4.06e-10]
# INFO:tensorflow:Optimization terminated with:
#   Message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   Objective function value: 0.000000
#   Number of iterations: 2035
#   Number of functions evaluations: 2256
# 5256      [5.51e-08, 1.94e-10]    [5.51e-08, 1.94e-10]    []
#
# Best model at step 5256:
#   train loss: 5.53e-08
#   test loss: 5.53e-08
#   test metric: []
#
# 'train' took 60.199123 s
#
# Saving loss history to /Users/auddy/Documents/Work/Projects/PINNs-StarFormation/loss.dat ...
# Saving training data to /Users/auddy/Documents/Work/Projects/PINNs-StarFormation/train.dat ...
# Saving test data to /Users/auddy/Documents/Work/Projects/PINNs-StarFormation/test.dat ...
# 2023-03-24 14:45:38.730081: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
# X = np.vstack((np.ravel(x), np.ravel(y), np.ravel(z))).T
X = np.linspace(xmin,1,1000).reshape(1000, 1)

t_0 = np.zeros(1000).reshape(1000, 1)
t_05 = 0.5*np.ones(1000).reshape(1000, 1)
t_1 = 1.0*np.ones(1000).reshape(1000, 1)

X_0 = np.hstack((X, t_0))
X_05 = np.hstack((X, t_05))
X_1 = np.hstack((X, t_1))

# %%
output_0 = model_test.predict(X_0)
output_05 = model_test.predict(X_05)
output_1 = model_test.predict(X_1)
plt.plot(X,output_0)
plt.plot(X,output_05)
plt.plot(X,output_1)
# Out:
# 2023-03-24 14:45:39.163908: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.

# %%
output_0 = model_test.predict(X)
output_05 = model_test.predict(X)
output_1 = model_test.predict(X)
plt.plot(X,output_0)
plt.plot(X,output_05)
plt.plot(X,output_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 output_0 = model_test.predict(X)
#       2 output_05 = model_test.predict(X)
#       3 output_1 = model_test.predict(X)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/deepxde/model.py:856, in Model.predict(self, x, operator, callbacks)
#     853 callbacks.on_predict_begin()
#     855 if operator is None:
# --> 856     y = self._outputs(False, x)
#     857     callbacks.on_predict_end()
#     858     return y
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/deepxde/model.py:497, in Model._outputs(self, training, inputs)
#     495 if backend_name == "tensorflow.compat.v1":
#     496     feed_dict = self.net.feed_dict(training, inputs)
# --> 497     return self.sess.run(self.outputs, feed_dict=feed_dict)
#     498 if backend_name in ["tensorflow", "pytorch", "paddle"]:
#     499     outs = self.outputs(training, inputs)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/client/session.py:968, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     965 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     967 try:
# --> 968   result = self._run(None, fetches, feed_dict, options_ptr,
#     969                      run_metadata_ptr)
#     970   if run_metadata:
#     971     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~/opt/miniconda3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/client/session.py:1165, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1161   np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    1163 if (not is_tensor_handle_feed and
#    1164     not subfeed_t.get_shape().is_compatible_with(np_val.shape)):
# -> 1165   raise ValueError(
#    1166       f'Cannot feed value of shape {str(np_val.shape)} for Tensor '
#    1167       f'{subfeed_t.name}, which has shape '
#    1168       f'{str(subfeed_t.get_shape())}')
#    1169 if not self.graph.is_feedable(subfeed_t):
#    1170   raise ValueError(f'Tensor {subfeed_t.name} may not be fed.')
#
# ValueError: Cannot feed value of shape (1000, 1) for Tensor Placeholder_2:0, which has shape (None, 2)
