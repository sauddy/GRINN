# %%
# !git clone https://github.com/sauddy/GRINN.git
# Out:
# Cloning into 'GRINN'...
# remote: Enumerating objects: 733, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 733 (delta 126), reused 176 (delta 93), pack-reused 506 (from 1)
# Receiving objects: 100% (733/733), 61.98 MiB | 30.28 MiB/s, done.
# Resolving deltas: 100% (348/348), done.

# %%
# %cd GRINN
# !git checkout Tirthankar_changes
# Out:
# /content/GRINN
# Branch 'Tirthankar_changes' set up to track remote branch 'Tirthankar_changes' from 'origin'.
# Switched to a new branch 'Tirthankar_changes'

# %%
# %cd /content/GRINN/GRINN_torch_code/Power spectrum perturbations
# Out:
# /content/GRINN/GRINN_torch_code/Power spectrum perturbations

# %%
# %run ./utilities/compare_model.py "/content/model (1).pth" 0.00,0.75,1.50,2.25,3.00 --fd-backend gpu --N-fd 1200 --nu-fd 0.25 --fd-backend gpu
# Out:
# Command line: --N-fd argument parsed as args.N_fd = 1200 (for all plots)
# Loaded PINN model from /content/model (1).pth
# Using GPU-accelerated FD solver (CUDA available)
#
# Generating density and velocity comparison plots...
# Spatial plot: Using N=1200 from command line argument
# Creating 5x3 comparison table for density...
# Time points: [0.   0.75 1.5  2.25 3.  ]
# ...
# Saved comparison plot to C:\Users\tirth\OneDrive\Desktop/model test plots/density_comparison_5x3_t0.0000_0.7500_1.5000_2.2500_3.0000.png
# Spatial plot: Using N=1200 from command line argument
# Creating 5x3 comparison table for velocity...
# Time points: [0.   0.75 1.5  2.25 3.  ]
# ...
# Saved comparison plot to C:\Users\tirth\OneDrive\Desktop/model test plots/velocity_comparison_5x3_t0.0000_0.7500_1.5000_2.2500_3.0000.png
# Done!

# %%
torch.cuda.empty_cache()
